# %%
# importing the requests library 
import requests 
import fitbit
import json
import pandas as pd
#gather_keys_oauth2.py
key = '22BC8S'
secret = 'b5e4b56e70b8ac891fb8417899db5e42'
token = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyMkJDOFMiLCJzdWIiOiI2MkhUNUYiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJzZXQgcmFjdCBybG9jIHJ3ZWkgcmhyIHJwcm8gcm51dCByc2xlIiwiZXhwIjoxNTcyODkwMzEyLCJpYXQiOjE1NzIyOTkxOTN9.iQyxHe2rTL9j3BxlN0ZD38LSDlZV-930mvMwyWHdJZw'

authd_client = fitbit.Fitbit(key, secret,
                             access_token=token, refresh_token='<refresh_token>')
data = authd_client.time_series('activities/heart', period='7d')

# %%
#print(data)
#type(data)

with open('result.json', 'w') as file:
    json.dump(data, file)
    
with open('result.json', 'r+') as file:
    data['activities_heart'] = data['activities-heart'] 
    json.dump(data, file)


# target the 'activities-heart' that
# is generated, and copy it to new object 'activities_heart' in the json.

# %%
raw_data = pd.read_json("result.json")#,
                       # lines=True,
                       # orient='columns')

raw_data.head(20)
# Out:
#                                     activities-heart  \
# 0  {'value': {'heartRateZones': [{'minutes': 1366...
# 1  {'value': {'heartRateZones': [{'minutes': 1079...
# 2  {'value': {'heartRateZones': [{'minutes': 838,...
# 3  {'value': {'heartRateZones': [{'minutes': 1175...
# 4  {'value': {'heartRateZones': [{'minutes': 1186...
# 5  {'value': {'heartRateZones': [{'minutes': 1389...
# 6  {'value': {'heartRateZones': [{'minutes': 1246...
#
#                                     activities_heart
# 0  {'value': {'heartRateZones': [{'minutes': 1366...
# 1  {'value': {'heartRateZones': [{'minutes': 1079...
# 2  {'value': {'heartRateZones': [{'minutes': 838,...
# 3  {'value': {'heartRateZones': [{'minutes': 1175...
# 4  {'value': {'heartRateZones': [{'minutes': 1186...
# 5  {'value': {'heartRateZones': [{'minutes': 1389...
# 6  {'value': {'heartRateZones': [{'minutes': 1246...

# %%
from pandas.io.json import json_normalize
HR = json_normalize(data=raw_data.activities_heart)
HR.head()
# Out:
#      dateTime value.customHeartRateZones  \
# 0  2019-10-28                         []
# 1  2019-10-29                         []
# 2  2019-10-30                         []
# 3  2019-10-31                         []
# 4  2019-11-01                         []
#
#                                 value.heartRateZones  value.restingHeartRate
# 0  [{'minutes': 1366, 'min': 30, 'caloriesOut': 2...                      62
# 1  [{'minutes': 1079, 'min': 30, 'caloriesOut': 2...                      61
# 2  [{'minutes': 838, 'min': 30, 'caloriesOut': 17...                      61
# 3  [{'minutes': 1175, 'min': 30, 'caloriesOut': 2...                      63
# 4  [{'minutes': 1186, 'min': 30, 'caloriesOut': 2...                      65

# %%
HR.to_csv('HR_Data.csv')
